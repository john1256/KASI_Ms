# %%
import os
import numpy as np
import cosmoprimo

# data dir in NERSC

NERSC_dir = '/pscratch/sd/j/john0712'
wigglez_data_dir = os.path.join(NERSC_dir, 'Practices','wigglez')
z_effs = [0.22, 0.41, 0.60, 0.78]

def read_wigglez_files(file_type,session, region='9-hr', data_dir = wigglez_data_dir):
    """a : 0.1<z<0.3, b : 0.3<z<0.5, c : 0.5<z<0.7, d : 0.7<z<0.9"""
    if session not in ['a','b', 'c', 'd']:
        
        raise ValueError("Session must be one of 'a', 'b', 'c', or 'd'")
    elif file_type not in ['cov', 'measurements', 'windows']:
        raise ValueError("File type must be one of 'cov', 'measurements', or 'windows'")
    filepath = os.path.join(data_dir, f'wigglez_jan11{session}_{file_type}.txt')
    with open(filepath, 'r') as f:
        data_lines = []
        prev_line_is_header = False
        for line in f:
            if line.startswith('#') and not prev_line_is_header:
                if 'region,' in line:
                    headers = line.split()
                    region_name = headers[headers.index('region,') - 1]
                    if region_name == region:
                        prev_line_is_header = True
                else:
                    continue
            elif line.startswith('#') and prev_line_is_header:
                if 'k / hMpc^-1' in line:
                    continue
                else:
                    break
            else:
                if prev_line_is_header:
                    line_arr = line.split()
                    line_arr = [float(x) for x in line_arr]
                    data_lines.append(line_arr)
                else:
                    continue
    return np.array(data_lines)

kbin=(0,100)

def get_wigglez_dataset(dataset = 'a'):
    klim = (2,20); 
    if dataset == 'a':
        regions = ['9-hr']
    else:
        regions = ['9-hr', '11-hr', '15-hr', '22-hr', '0-hr', '1-hr', '3-hr']

    cov = [read_wigglez_files('cov',dataset, region=reg)[klim[0]:klim[1],klim[0]:klim[1]] for reg in regions]
    
    k_measured = [read_wigglez_files('measurements',dataset, region=reg)[klim[0]:klim[1],0] for reg in regions]
    power_measured = [read_wigglez_files('measurements',dataset, region=reg)[klim[0]:klim[1],3] for reg in regions]
    windows = [read_wigglez_files('windows',dataset, region=reg)[klim[0]:klim[1], kbin[0]:kbin[1]] for reg in regions]
    return k_measured, power_measured, windows, cov

kbands = np.loadtxt(os.path.join(wigglez_data_dir, 'wigglez_jan11kbands.txt'))[kbin[0]:kbin[1]]

from desilike.theories.galaxy_clustering import KaiserTracerPowerSpectrumMultipoles, DirectPowerSpectrumTemplate
from desilike.observables.galaxy_clustering import TracerPowerSpectrumMultipolesObservable
from desilike.likelihoods import ObservablesGaussianLikelihood
from scipy.linalg import block_diag
from desilike import setup_logging
from desilike.theories import Cosmoprimo

def make_wigglez_likelihood(dataset='a', varied_params=None):
    k_measured, power_measured, windows, cov = get_wigglez_dataset(dataset)
    wigglez_cosmo = cosmoprimo.Cosmology(
        omega_cdm=0.1153,
        omega_b=0.02238,
        h=0.689,
        tau_reio = 0.083,
        n_s = 0.964,
        logA = 3.084, engine='class'
    )
    #wigglez_cosmo = Cosmoprimo(fiducial='DESI', **wigglez_params)
    data_name = ['a', 'b', 'c', 'd']
    k_measured, power_measured, windows, cov = get_wigglez_dataset(dataset)
    template = DirectPowerSpectrumTemplate(fiducial=wigglez_cosmo, z=z_effs[data_name.index(dataset)])
    #for param in list(set(['omega_cdm', 'omega_b', 'h', 'tau_reio', 'n_s', 'logA']) - set(varied_params)):
    #    template.params[param].update(fixed=True)
    theory = KaiserTracerPowerSpectrumMultipoles(template=template, k=kbands)
    observables = []
    cov_tot = block_diag(*cov)
    for i in range(len(k_measured)):
        observable = TracerPowerSpectrumMultipolesObservable(theory=theory, data=power_measured[i], wmatrix=windows[i], ells=(0,), k=k_measured[i], kin=kbands, ellsin=(0,))
        observables.append(observable)
    likelihood = ObservablesGaussianLikelihood(observables=observables, covariance=cov_tot)
    for param in list(set(['omega_cdm', 'omega_b', 'h', 'tau_reio', 'n_s', 'logA', 'b1', 'sn0']) - set(varied_params)):
        likelihood.all_params[param].update(fixed=True)
    return likelihood
    
#from desilike.samples import Chain
#chain_for_cov = Chain.load('../_tests/chain_wigglez_a_b1_omega_cdm.npy').remove_burnin(0.4)

setup_logging()
for dataset in ['d']:
    likelihood = make_wigglez_likelihood(dataset, varied_params=['omega_cdm', 'b1'])
    likelihood.all_params['b1'].update(prior={'limits': [0., 5.], 'latex': 'b_1'})
    likelihood.all_params['omega_cdm'].update(prior={'limits': [0.01, 0.4], 'latex': r'\omega_{cdm}'})
    #likelihood.all_params['h'].update(prior={'limits': [0.4, 1.0], 'latex': 'h'})
    
    from desilike.samplers import MCMCSampler
    sampler = MCMCSampler(likelihood,proposal_scale=1.2,save_fn=f'../_tests/chain_wigglez_{dataset}_b1_omega_cdm.npy')
    sampler.run(check={'max_eigen_gr': 0.01}, max_iterations=10000)
# Out:
# [000001.39] [0/1] 12-12 02:16  MCMCSampler               INFO     Varied parameters: ['omega_cdm', 'b1'].
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     Found speeds:
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.theories.primordial_cosmology.Cosmoprimo object at 0x7f530c179cc0>: 174.62 iterations / second - 0.006 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.base.APEffect object at 0x7f530c179cf0>: 24.51 iterations / second - 0.041 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.power_template.DirectPowerSpectrumTemplate object at 0x7f5488186530>: 1.15 iterations / second - 0.869 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.full_shape.KaiserPowerSpectrumMultipoles object at 0x7f530c267a30>: 649.34 iterations / second - 0.002 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.theories.galaxy_clustering.full_shape.KaiserTracerPowerSpectrumMultipoles object at 0x7f530c130d60>: 8835.69 iterations / second - 0.000 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c17d660>: 18339.76 iterations / second - 0.000 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c13dea0>: 98922.26 iterations / second - 0.000 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c17ceb0>: 24921.59 iterations / second - 0.000 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f5488185240>: 202623.38 iterations / second - 0.000 s / iteration
# [000012.50] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c17c700>: 26647.42 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c266e00>: 225500.22 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c133df0>: 26783.55 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c2661a0>: 215092.51 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c265990>: 27557.84 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c2646d0>: 215092.51 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c2673a0>: 25731.93 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c265f30>: 221920.85 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.window.WindowedPowerSpectrumMultipoles object at 0x7f530c266140>: 27869.13 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.observables.galaxy_clustering.power_spectrum.TracerPowerSpectrumMultipolesObservable object at 0x7f530c265270>: 223101.28 iterations / second - 0.000 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - <desilike.likelihoods.base.ObservablesGaussianLikelihood object at 0x7f530c13dab0>: 1571.90 iterations / second - 0.001 s / iteration
# [000012.51] [0/1] 12-12 02:16  BasePipeline              INFO     - total speed: 1.09 iterations / second - 0.9179 s / iteration
# [000012.51] [0/1] 12-12 02:16  MCMCSampler               INFO     Oversampling with factors:
# [000012.51] [0/1] 12-12 02:16  MCMCSampler               INFO     1: ['omega_cdm']
# [000012.51] [0/1] 12-12 02:16  MCMCSampler               INFO     14: ['b1']
# [000012.52] [0/1] 12-12 02:16  MCMCSampler               INFO     Using provided covariance matrix.
# [000012.81] [0/1] 12-12 02:16  MCMCSampler               INFO     Could *not* vmap input likelihood. Set logging level to debug (setup_logging("debug")) to get full stack trace.
# [000012.83] [0/1] 12-12 02:16  MCMCSampler               INFO     Could *not* jit input likelihood.
# [000044.52] [0/1] 12-12 02:17  MCMCSampler               INFO     387 steps, acceptance rate 0.119.
# [000075.49] [0/1] 12-12 02:17  MCMCSampler               INFO     793 steps, acceptance rate 0.129.
# [000107.10] [0/1] 12-12 02:18  MCMCSampler               INFO     1197 steps, acceptance rate 0.119.
# [000137.53] [0/1] 12-12 02:18  MCMCSampler               INFO     1552 steps, acceptance rate 0.119.
# [000167.87] [0/1] 12-12 02:19  MCMCSampler               INFO     1937 steps, acceptance rate 0.123.
# [000198.64] [0/1] 12-12 02:19  MCMCSampler               INFO     2351 steps, acceptance rate 0.125.
# [000204.51] [0/1] 12-12 02:19  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000204.52] [0/1] 12-12 02:19  MCMCSampler               INFO     Diagnostics:
# [000204.53] [0/1] 12-12 02:19  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 8.67; not < 0.01.
# [000204.55] [0/1] 12-12 02:19  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 9.14.
# [000204.63] [0/1] 12-12 02:19  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 11.
# [000204.64] [0/1] 12-12 02:19  Diagnostics               INFO     - max Geweke is 4.1.
# [000204.65] [0/1] 12-12 02:19  Diagnostics               INFO     - Geweke p-value is 0.00349.
# [000204.65] [0/1] 12-12 02:19  Diagnostics               INFO     - effective sample size = (150 iterations / integrated autocorrelation time) is 8.54.
# [000204.65] [0/1] 12-12 02:19  Diagnostics               INFO     - current mean acceptance rate is 0.124.
# [000204.65] [0/1] 12-12 02:19  Diagnostics               INFO     - total mean acceptance rate is 0.124.
# [000204.66] [0/1] 12-12 02:19  MCMCSampler               INFO     Updating proposal covariance.
# /global/common/software/desi/users/adematti/perlmutter/cosmodesiconda/20240118-1.0.0/conda/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# [000236.63] [0/1] 12-12 02:20  MCMCSampler               INFO     362 steps, acceptance rate 0.655.
# [000244.63] [0/1] 12-12 02:20  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000244.63] [0/1] 12-12 02:20  MCMCSampler               INFO     Diagnostics:
# [000244.64] [0/1] 12-12 02:20  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 2.02; not < 0.01.
# [000244.65] [0/1] 12-12 02:20  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 2.27.
# [000244.68] [0/1] 12-12 02:20  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 3.45.
# [000244.68] [0/1] 12-12 02:20  Diagnostics               INFO     - max Geweke is 13.8.
# [000244.68] [0/1] 12-12 02:20  Diagnostics               INFO     - Geweke p-value is 0.00063.
# [000244.68] [0/1] 12-12 02:20  Diagnostics               INFO     - effective sample size = (300 iterations / integrated autocorrelation time) is 9.34.
# [000244.68] [0/1] 12-12 02:20  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.534.
# [000244.69] [0/1] 12-12 02:20  Diagnostics               INFO     - current mean acceptance rate is 0.658.
# [000244.69] [0/1] 12-12 02:20  Diagnostics               INFO     - total mean acceptance rate is 0.208.
# [000244.70] [0/1] 12-12 02:20  MCMCSampler               INFO     Updating proposal covariance.
# [000274.72] [0/1] 12-12 02:21  MCMCSampler               INFO     370 steps, acceptance rate 0.697.
# [000279.60] [0/1] 12-12 02:21  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000279.60] [0/1] 12-12 02:21  MCMCSampler               INFO     Diagnostics:
# [000279.62] [0/1] 12-12 02:21  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 2.81; not < 0.01.
# [000279.63] [0/1] 12-12 02:21  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 3.05.
# [000279.67] [0/1] 12-12 02:21  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 4.61.
# [000279.67] [0/1] 12-12 02:21  Diagnostics               INFO     - max Geweke is 2.65.
# [000279.67] [0/1] 12-12 02:21  Diagnostics               INFO     - Geweke p-value is 0.521.
# [000279.68] [0/1] 12-12 02:21  Diagnostics               INFO     - effective sample size = (450 iterations / integrated autocorrelation time) is 8.91.
# [000279.68] [0/1] 12-12 02:21  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.364.
# [000279.68] [0/1] 12-12 02:21  Diagnostics               INFO     - current mean acceptance rate is 0.696.
# [000279.68] [0/1] 12-12 02:21  Diagnostics               INFO     - total mean acceptance rate is 0.271.
# [000280.61] [0/1] 12-12 02:21  MCMCSampler               INFO     Updating proposal covariance.
# [000311.49] [0/1] 12-12 02:21  MCMCSampler               INFO     444 steps, acceptance rate 0.664.
# [000311.54] [0/1] 12-12 02:21  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000311.55] [0/1] 12-12 02:21  MCMCSampler               INFO     Diagnostics:
# [000311.56] [0/1] 12-12 02:21  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 1.58; not < 0.01.
# [000311.57] [0/1] 12-12 02:21  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 1.27.
# [000311.61] [0/1] 12-12 02:21  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.88.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - max Geweke is 4.25.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - Geweke p-value is 0.226.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - effective sample size = (600 iterations / integrated autocorrelation time) is 15.3.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.287.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - current mean acceptance rate is 0.664.
# [000311.62] [0/1] 12-12 02:21  Diagnostics               INFO     - total mean acceptance rate is 0.319.
# [000311.63] [0/1] 12-12 02:21  MCMCSampler               INFO     Updating proposal covariance.
# [000342.25] [0/1] 12-12 02:22  MCMCSampler               INFO     303 steps, acceptance rate 0.624.
# [000358.14] [0/1] 12-12 02:22  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000358.14] [0/1] 12-12 02:22  MCMCSampler               INFO     Diagnostics:
# [000358.16] [0/1] 12-12 02:22  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.94; not < 0.01.
# [000358.17] [0/1] 12-12 02:22  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.683.
# [000358.21] [0/1] 12-12 02:22  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.79.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - max Geweke is 2.79.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - Geweke p-value is 0.273.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - effective sample size = (750 iterations / integrated autocorrelation time) is 19.3.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0337.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - current mean acceptance rate is 0.628.
# [000358.22] [0/1] 12-12 02:22  Diagnostics               INFO     - total mean acceptance rate is 0.353.
# [000358.24] [0/1] 12-12 02:22  MCMCSampler               INFO     Updating proposal covariance.
# [000388.67] [0/1] 12-12 02:22  MCMCSampler               INFO     233 steps, acceptance rate 0.614.
# [000414.90] [0/1] 12-12 02:23  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000414.90] [0/1] 12-12 02:23  MCMCSampler               INFO     Diagnostics:
# [000414.92] [0/1] 12-12 02:23  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.956; not < 0.01.
# [000414.94] [0/1] 12-12 02:23  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 1.08.
# [000415.02] [0/1] 12-12 02:23  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.95.
# [000415.02] [0/1] 12-12 02:23  Diagnostics               INFO     - max Geweke is 5.49.
# [000415.03] [0/1] 12-12 02:23  Diagnostics               INFO     - Geweke p-value is 0.242.
# [000415.03] [0/1] 12-12 02:23  Diagnostics               INFO     - effective sample size = (900 iterations / integrated autocorrelation time) is 11.5.
# [000415.03] [0/1] 12-12 02:23  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.504.
# [000415.03] [0/1] 12-12 02:23  Diagnostics               INFO     - current mean acceptance rate is 0.607.
# [000415.03] [0/1] 12-12 02:23  Diagnostics               INFO     - total mean acceptance rate is 0.38.
# [000415.04] [0/1] 12-12 02:23  MCMCSampler               INFO     Updating proposal covariance.
# [000445.76] [0/1] 12-12 02:23  MCMCSampler               INFO     289 steps, acceptance rate 0.606.
# [000467.88] [0/1] 12-12 02:24  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000467.89] [0/1] 12-12 02:24  MCMCSampler               INFO     Diagnostics:
# [000467.90] [0/1] 12-12 02:24  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.314; not < 0.01.
# [000467.92] [0/1] 12-12 02:24  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.24.
# [000467.97] [0/1] 12-12 02:24  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.53.
# [000467.97] [0/1] 12-12 02:24  Diagnostics               INFO     - max Geweke is 3.94.
# [000467.97] [0/1] 12-12 02:24  Diagnostics               INFO     - Geweke p-value is 0.144.
# [000467.98] [0/1] 12-12 02:24  Diagnostics               INFO     - effective sample size = (1050 iterations / integrated autocorrelation time) is 21.
# [000467.98] [0/1] 12-12 02:24  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.566.
# [000467.98] [0/1] 12-12 02:24  Diagnostics               INFO     - current mean acceptance rate is 0.584.
# [000467.98] [0/1] 12-12 02:24  Diagnostics               INFO     - total mean acceptance rate is 0.4.
# [000467.99] [0/1] 12-12 02:24  MCMCSampler               INFO     Updating proposal covariance.
# [000498.56] [0/1] 12-12 02:24  MCMCSampler               INFO     324 steps, acceptance rate 0.630.
# [000513.92] [0/1] 12-12 02:25  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000513.92] [0/1] 12-12 02:25  MCMCSampler               INFO     Diagnostics:
# [000513.94] [0/1] 12-12 02:25  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 1.02; not < 0.01.
# [000513.95] [0/1] 12-12 02:25  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.751.
# [000514.00] [0/1] 12-12 02:25  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.96.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - max Geweke is 1.66.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - Geweke p-value is 0.544.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - effective sample size = (1200 iterations / integrated autocorrelation time) is 21.6.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0979.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - current mean acceptance rate is 0.622.
# [000514.01] [0/1] 12-12 02:25  Diagnostics               INFO     - total mean acceptance rate is 0.418.
# [000514.03] [0/1] 12-12 02:25  MCMCSampler               INFO     Updating proposal covariance.
# [000544.36] [0/1] 12-12 02:25  MCMCSampler               INFO     334 steps, acceptance rate 0.629.
# [000557.04] [0/1] 12-12 02:25  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000557.05] [0/1] 12-12 02:25  MCMCSampler               INFO     Diagnostics:
# [000557.06] [0/1] 12-12 02:25  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.998; not < 0.01.
# [000557.07] [0/1] 12-12 02:25  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.787.
# [000557.13] [0/1] 12-12 02:25  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.61.
# [000557.13] [0/1] 12-12 02:25  Diagnostics               INFO     - max Geweke is 3.9.
# [000557.13] [0/1] 12-12 02:25  Diagnostics               INFO     - Geweke p-value is 0.454.
# [000557.14] [0/1] 12-12 02:25  Diagnostics               INFO     - effective sample size = (1350 iterations / integrated autocorrelation time) is 15.1.
# [000557.14] [0/1] 12-12 02:25  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.382.
# [000557.14] [0/1] 12-12 02:25  Diagnostics               INFO     - current mean acceptance rate is 0.615.
# [000557.14] [0/1] 12-12 02:25  Diagnostics               INFO     - total mean acceptance rate is 0.434.
# [000557.15] [0/1] 12-12 02:25  MCMCSampler               INFO     Updating proposal covariance.
# [000587.48] [0/1] 12-12 02:26  MCMCSampler               INFO     338 steps, acceptance rate 0.651.
# [000599.36] [0/1] 12-12 02:26  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000599.36] [0/1] 12-12 02:26  MCMCSampler               INFO     Diagnostics:
# [000599.39] [0/1] 12-12 02:26  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.844; not < 0.01.
# [000599.40] [0/1] 12-12 02:26  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.95.
# [000599.46] [0/1] 12-12 02:26  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.21.
# [000599.46] [0/1] 12-12 02:26  Diagnostics               INFO     - max Geweke is 0.94.
# [000599.46] [0/1] 12-12 02:26  Diagnostics               INFO     - Geweke p-value is 0.0343.
# [000599.47] [0/1] 12-12 02:26  Diagnostics               INFO     - effective sample size = (1500 iterations / integrated autocorrelation time) is 10.8.
# [000599.47] [0/1] 12-12 02:26  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.364.
# [000599.47] [0/1] 12-12 02:26  Diagnostics               INFO     - current mean acceptance rate is 0.641.
# [000599.47] [0/1] 12-12 02:26  Diagnostics               INFO     - total mean acceptance rate is 0.448.
# [000599.48] [0/1] 12-12 02:26  MCMCSampler               INFO     Updating proposal covariance.
# [000629.69] [0/1] 12-12 02:26  MCMCSampler               INFO     317 steps, acceptance rate 0.606.
# [000648.31] [0/1] 12-12 02:27  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000648.32] [0/1] 12-12 02:27  MCMCSampler               INFO     Diagnostics:
# [000648.33] [0/1] 12-12 02:27  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.281; not < 0.01.
# [000648.34] [0/1] 12-12 02:27  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.274.
# [000648.38] [0/1] 12-12 02:27  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.558.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - max Geweke is 1.86.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - Geweke p-value is 0.901.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - effective sample size = (1650 iterations / integrated autocorrelation time) is 20.3.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - max variation of integrated autocorrelation time is 2.16.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - current mean acceptance rate is 0.602.
# [000648.39] [0/1] 12-12 02:27  Diagnostics               INFO     - total mean acceptance rate is 0.459.
# [000648.40] [0/1] 12-12 02:27  MCMCSampler               INFO     Updating proposal covariance.
# [000678.92] [0/1] 12-12 02:27  MCMCSampler               INFO     319 steps, acceptance rate 0.661.
# [000691.74] [0/1] 12-12 02:27  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000691.74] [0/1] 12-12 02:27  MCMCSampler               INFO     Diagnostics:
# [000691.76] [0/1] 12-12 02:27  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.784; not < 0.01.
# [000691.78] [0/1] 12-12 02:27  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.315.
# [000691.84] [0/1] 12-12 02:27  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.891.
# [000691.84] [0/1] 12-12 02:27  Diagnostics               INFO     - max Geweke is 1.14.
# [000691.85] [0/1] 12-12 02:27  Diagnostics               INFO     - Geweke p-value is 0.462.
# [000691.85] [0/1] 12-12 02:27  Diagnostics               INFO     - effective sample size = (1800 iterations / integrated autocorrelation time) is 40.9.
# [000691.85] [0/1] 12-12 02:27  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.848.
# [000691.85] [0/1] 12-12 02:27  Diagnostics               INFO     - current mean acceptance rate is 0.652.
# [000691.85] [0/1] 12-12 02:27  Diagnostics               INFO     - total mean acceptance rate is 0.471.
# [000691.86] [0/1] 12-12 02:27  MCMCSampler               INFO     Updating proposal covariance.
# [000723.66] [0/1] 12-12 02:28  MCMCSampler               INFO     343 steps, acceptance rate 0.598.
# [000740.33] [0/1] 12-12 02:28  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000740.34] [0/1] 12-12 02:28  MCMCSampler               INFO     Diagnostics:
# [000740.35] [0/1] 12-12 02:28  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.565; not < 0.01.
# [000740.36] [0/1] 12-12 02:28  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.233.
# [000740.43] [0/1] 12-12 02:28  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.577.
# [000740.43] [0/1] 12-12 02:28  Diagnostics               INFO     - max Geweke is 1.76.
# [000740.44] [0/1] 12-12 02:28  Diagnostics               INFO     - Geweke p-value is 0.22.
# [000740.44] [0/1] 12-12 02:28  Diagnostics               INFO     - effective sample size = (1950 iterations / integrated autocorrelation time) is 48.8.
# [000740.44] [0/1] 12-12 02:28  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.102.
# [000740.44] [0/1] 12-12 02:28  Diagnostics               INFO     - current mean acceptance rate is 0.599.
# [000740.44] [0/1] 12-12 02:28  Diagnostics               INFO     - total mean acceptance rate is 0.479.
# [000740.46] [0/1] 12-12 02:28  MCMCSampler               INFO     Updating proposal covariance.
# [000772.23] [0/1] 12-12 02:29  MCMCSampler               INFO     354 steps, acceptance rate 0.627.
# [000783.06] [0/1] 12-12 02:29  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000783.07] [0/1] 12-12 02:29  MCMCSampler               INFO     Diagnostics:
# [000783.09] [0/1] 12-12 02:29  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.539; not < 0.01.
# [000783.10] [0/1] 12-12 02:29  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.118.
# [000783.17] [0/1] 12-12 02:29  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.831.
# [000783.17] [0/1] 12-12 02:29  Diagnostics               INFO     - max Geweke is 0.288.
# [000783.17] [0/1] 12-12 02:29  Diagnostics               INFO     - Geweke p-value is 0.548.
# [000783.18] [0/1] 12-12 02:29  Diagnostics               INFO     - effective sample size = (2100 iterations / integrated autocorrelation time) (reliable) is 70.5.
# [000783.18] [0/1] 12-12 02:29  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.361.
# [000783.18] [0/1] 12-12 02:29  Diagnostics               INFO     - current mean acceptance rate is 0.636.
# [000783.18] [0/1] 12-12 02:29  Diagnostics               INFO     - total mean acceptance rate is 0.487.
# [000783.19] [0/1] 12-12 02:29  MCMCSampler               INFO     Updating proposal covariance.
# [000813.93] [0/1] 12-12 02:30  MCMCSampler               INFO     353 steps, acceptance rate 0.595.
# [000825.47] [0/1] 12-12 02:30  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000825.47] [0/1] 12-12 02:30  MCMCSampler               INFO     Diagnostics:
# [000825.48] [0/1] 12-12 02:30  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.122; not < 0.01.
# [000825.49] [0/1] 12-12 02:30  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.128.
# [000825.54] [0/1] 12-12 02:30  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.232.
# [000825.55] [0/1] 12-12 02:30  Diagnostics               INFO     - max Geweke is 0.663.
# [000825.55] [0/1] 12-12 02:30  Diagnostics               INFO     - Geweke p-value is 0.523.
# [000825.55] [0/1] 12-12 02:30  Diagnostics               INFO     - effective sample size = (2250 iterations / integrated autocorrelation time) (reliable) is 83.4.
# [000825.55] [0/1] 12-12 02:30  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.104.
# [000825.56] [0/1] 12-12 02:30  Diagnostics               INFO     - current mean acceptance rate is 0.596.
# [000825.56] [0/1] 12-12 02:30  Diagnostics               INFO     - total mean acceptance rate is 0.493.
# [000826.54] [0/1] 12-12 02:30  MCMCSampler               INFO     Updating proposal covariance.
# [000857.50] [0/1] 12-12 02:30  MCMCSampler               INFO     363 steps, acceptance rate 0.658.
# [000870.21] [0/1] 12-12 02:30  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000870.21] [0/1] 12-12 02:30  MCMCSampler               INFO     Diagnostics:
# [000870.23] [0/1] 12-12 02:30  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.342; not < 0.01.
# [000870.24] [0/1] 12-12 02:30  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.141.
# [000870.31] [0/1] 12-12 02:30  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.12.
# [000870.31] [0/1] 12-12 02:30  Diagnostics               INFO     - max Geweke is 0.948.
# [000870.32] [0/1] 12-12 02:30  Diagnostics               INFO     - Geweke p-value is 0.101.
# [000870.32] [0/1] 12-12 02:30  Diagnostics               INFO     - effective sample size = (2400 iterations / integrated autocorrelation time) (reliable) is 63.8.
# [000870.32] [0/1] 12-12 02:30  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.283.
# [000870.32] [0/1] 12-12 02:30  Diagnostics               INFO     - current mean acceptance rate is 0.632.
# [000870.32] [0/1] 12-12 02:30  Diagnostics               INFO     - total mean acceptance rate is 0.5.
# [000870.34] [0/1] 12-12 02:30  MCMCSampler               INFO     Updating proposal covariance.
# [000900.65] [0/1] 12-12 02:31  MCMCSampler               INFO     320 steps, acceptance rate 0.631.
# [000911.60] [0/1] 12-12 02:31  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000911.60] [0/1] 12-12 02:31  MCMCSampler               INFO     Diagnostics:
# [000911.61] [0/1] 12-12 02:31  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.366; not < 0.01.
# [000911.62] [0/1] 12-12 02:31  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.124.
# [000911.70] [0/1] 12-12 02:31  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.729.
# [000911.70] [0/1] 12-12 02:31  Diagnostics               INFO     - max Geweke is 2.26.
# [000911.71] [0/1] 12-12 02:31  Diagnostics               INFO     - Geweke p-value is 0.462.
# [000911.71] [0/1] 12-12 02:31  Diagnostics               INFO     - effective sample size = (2550 iterations / integrated autocorrelation time) (reliable) is 50.9.
# [000911.71] [0/1] 12-12 02:31  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.262.
# [000911.71] [0/1] 12-12 02:31  Diagnostics               INFO     - current mean acceptance rate is 0.632.
# [000911.71] [0/1] 12-12 02:31  Diagnostics               INFO     - total mean acceptance rate is 0.506.
# [000911.72] [0/1] 12-12 02:31  MCMCSampler               INFO     Updating proposal covariance.
# [000942.18] [0/1] 12-12 02:32  MCMCSampler               INFO     378 steps, acceptance rate 0.627.
# [000948.57] [0/1] 12-12 02:32  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000948.58] [0/1] 12-12 02:32  MCMCSampler               INFO     Diagnostics:
# [000948.59] [0/1] 12-12 02:32  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.361; not < 0.01.
# [000948.61] [0/1] 12-12 02:32  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.177.
# [000948.71] [0/1] 12-12 02:32  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.716.
# [000948.71] [0/1] 12-12 02:32  Diagnostics               INFO     - max Geweke is 1.85.
# [000948.72] [0/1] 12-12 02:32  Diagnostics               INFO     - Geweke p-value is 0.387.
# [000948.73] [0/1] 12-12 02:32  Diagnostics               INFO     - effective sample size = (2700 iterations / integrated autocorrelation time) (reliable) is 69.9.
# [000948.73] [0/1] 12-12 02:32  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.298.
# [000948.73] [0/1] 12-12 02:32  Diagnostics               INFO     - current mean acceptance rate is 0.636.
# [000948.73] [0/1] 12-12 02:32  Diagnostics               INFO     - total mean acceptance rate is 0.512.
# [000948.75] [0/1] 12-12 02:32  MCMCSampler               INFO     Updating proposal covariance.
# [000979.31] [0/1] 12-12 02:32  MCMCSampler               INFO     364 steps, acceptance rate 0.640.
# [000989.31] [0/1] 12-12 02:32  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [000989.32] [0/1] 12-12 02:32  MCMCSampler               INFO     Diagnostics:
# [000989.33] [0/1] 12-12 02:32  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.146; not < 0.01.
# [000989.34] [0/1] 12-12 02:32  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0146.
# [000989.42] [0/1] 12-12 02:32  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.744.
# [000989.43] [0/1] 12-12 02:32  Diagnostics               INFO     - max Geweke is 0.864.
# [000989.43] [0/1] 12-12 02:32  Diagnostics               INFO     - Geweke p-value is 0.0635.
# [000989.43] [0/1] 12-12 02:32  Diagnostics               INFO     - effective sample size = (2850 iterations / integrated autocorrelation time) (reliable) is 72.4.
# [000989.43] [0/1] 12-12 02:32  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0296.
# [000989.44] [0/1] 12-12 02:32  Diagnostics               INFO     - current mean acceptance rate is 0.633.
# [000989.44] [0/1] 12-12 02:32  Diagnostics               INFO     - total mean acceptance rate is 0.517.
# [000989.45] [0/1] 12-12 02:32  MCMCSampler               INFO     Updating proposal covariance.
# [001020.31] [0/1] 12-12 02:33  MCMCSampler               INFO     326 steps, acceptance rate 0.632.
# [001035.48] [0/1] 12-12 02:33  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001035.49] [0/1] 12-12 02:33  MCMCSampler               INFO     Diagnostics:
# [001035.50] [0/1] 12-12 02:33  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0605; not < 0.01.
# [001035.52] [0/1] 12-12 02:33  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.007.
# [001035.64] [0/1] 12-12 02:33  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.217.
# [001035.64] [0/1] 12-12 02:33  Diagnostics               INFO     - max Geweke is 1.44.
# [001035.65] [0/1] 12-12 02:33  Diagnostics               INFO     - Geweke p-value is 0.747.
# [001035.65] [0/1] 12-12 02:33  Diagnostics               INFO     - effective sample size = (3000 iterations / integrated autocorrelation time) (reliable) is 80.
# [001035.65] [0/1] 12-12 02:33  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0518.
# [001035.65] [0/1] 12-12 02:33  Diagnostics               INFO     - current mean acceptance rate is 0.622.
# [001035.65] [0/1] 12-12 02:33  Diagnostics               INFO     - total mean acceptance rate is 0.522.
# [001035.66] [0/1] 12-12 02:33  MCMCSampler               INFO     Updating proposal covariance.
# [001066.14] [0/1] 12-12 02:34  MCMCSampler               INFO     334 steps, acceptance rate 0.641.
# [001077.67] [0/1] 12-12 02:34  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001077.67] [0/1] 12-12 02:34  MCMCSampler               INFO     Diagnostics:
# [001077.68] [0/1] 12-12 02:34  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.392; not < 0.01.
# [001077.70] [0/1] 12-12 02:34  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.175.
# [001077.78] [0/1] 12-12 02:34  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.824.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - max Geweke is 0.838.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - Geweke p-value is 0.325.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - effective sample size = (3150 iterations / integrated autocorrelation time) (reliable) is 81.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0453.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - current mean acceptance rate is 0.64.
# [001077.79] [0/1] 12-12 02:34  Diagnostics               INFO     - total mean acceptance rate is 0.526.
# [001077.80] [0/1] 12-12 02:34  MCMCSampler               INFO     Updating proposal covariance.
# [001108.69] [0/1] 12-12 02:34  MCMCSampler               INFO     324 steps, acceptance rate 0.664.
# [001119.81] [0/1] 12-12 02:35  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001119.82] [0/1] 12-12 02:35  MCMCSampler               INFO     Diagnostics:
# [001119.83] [0/1] 12-12 02:35  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0961; not < 0.01.
# [001119.84] [0/1] 12-12 02:35  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.00373.
# [001119.93] [0/1] 12-12 02:35  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.573.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - max Geweke is 0.904.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - Geweke p-value is 0.711.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - effective sample size = (3300 iterations / integrated autocorrelation time) (reliable) is 88.1.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0467.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - current mean acceptance rate is 0.655.
# [001119.94] [0/1] 12-12 02:35  Diagnostics               INFO     - total mean acceptance rate is 0.531.
# [001119.96] [0/1] 12-12 02:35  MCMCSampler               INFO     Updating proposal covariance.
# [001150.38] [0/1] 12-12 02:35  MCMCSampler               INFO     298 steps, acceptance rate 0.611.
# [001168.37] [0/1] 12-12 02:35  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001168.38] [0/1] 12-12 02:35  MCMCSampler               INFO     Diagnostics:
# [001168.39] [0/1] 12-12 02:35  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0366; not < 0.01.
# [001168.41] [0/1] 12-12 02:35  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.00169.
# [001168.50] [0/1] 12-12 02:35  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.44.
# [001168.50] [0/1] 12-12 02:35  Diagnostics               INFO     - max Geweke is 0.578.
# [001168.50] [0/1] 12-12 02:35  Diagnostics               INFO     - Geweke p-value is 0.414.
# [001168.51] [0/1] 12-12 02:35  Diagnostics               INFO     - effective sample size = (3450 iterations / integrated autocorrelation time) (reliable) is 91.7.
# [001168.51] [0/1] 12-12 02:35  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.00412.
# [001168.51] [0/1] 12-12 02:35  Diagnostics               INFO     - current mean acceptance rate is 0.591.
# [001168.51] [0/1] 12-12 02:35  Diagnostics               INFO     - total mean acceptance rate is 0.533.
# [001168.52] [0/1] 12-12 02:35  MCMCSampler               INFO     Updating proposal covariance.
# [001199.33] [0/1] 12-12 02:36  MCMCSampler               INFO     343 steps, acceptance rate 0.673.
# [001211.54] [0/1] 12-12 02:36  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001211.55] [0/1] 12-12 02:36  MCMCSampler               INFO     Diagnostics:
# [001211.56] [0/1] 12-12 02:36  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.289; not < 0.01.
# [001211.57] [0/1] 12-12 02:36  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0777.
# [001211.66] [0/1] 12-12 02:36  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.467.
# [001211.67] [0/1] 12-12 02:36  Diagnostics               INFO     - max Geweke is 0.727.
# [001211.67] [0/1] 12-12 02:36  Diagnostics               INFO     - Geweke p-value is 0.127.
# [001211.67] [0/1] 12-12 02:36  Diagnostics               INFO     - effective sample size = (3600 iterations / integrated autocorrelation time) (reliable) is 92.7.
# [001211.67] [0/1] 12-12 02:36  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0311.
# [001211.68] [0/1] 12-12 02:36  Diagnostics               INFO     - current mean acceptance rate is 0.655.
# [001211.68] [0/1] 12-12 02:36  Diagnostics               INFO     - total mean acceptance rate is 0.537.
# [001211.69] [0/1] 12-12 02:36  MCMCSampler               INFO     Updating proposal covariance.
# [001241.87] [0/1] 12-12 02:37  MCMCSampler               INFO     363 steps, acceptance rate 0.650.
# [001249.68] [0/1] 12-12 02:37  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001249.68] [0/1] 12-12 02:37  MCMCSampler               INFO     Diagnostics:
# [001249.70] [0/1] 12-12 02:37  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.298; not < 0.01.
# [001249.71] [0/1] 12-12 02:37  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0854.
# [001249.80] [0/1] 12-12 02:37  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.403.
# [001249.81] [0/1] 12-12 02:37  Diagnostics               INFO     - max Geweke is 1.57.
# [001249.81] [0/1] 12-12 02:37  Diagnostics               INFO     - Geweke p-value is 0.612.
# [001249.82] [0/1] 12-12 02:37  Diagnostics               INFO     - effective sample size = (3750 iterations / integrated autocorrelation time) (reliable) is 92.7.
# [001249.82] [0/1] 12-12 02:37  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0397.
# [001249.82] [0/1] 12-12 02:37  Diagnostics               INFO     - current mean acceptance rate is 0.649.
# [001249.82] [0/1] 12-12 02:37  Diagnostics               INFO     - total mean acceptance rate is 0.541.
# [001249.83] [0/1] 12-12 02:37  MCMCSampler               INFO     Updating proposal covariance.
# [001281.64] [0/1] 12-12 02:37  MCMCSampler               INFO     297 steps, acceptance rate 0.673.
# [001293.76] [0/1] 12-12 02:38  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001293.77] [0/1] 12-12 02:38  MCMCSampler               INFO     Diagnostics:
# [001293.79] [0/1] 12-12 02:38  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.126; not < 0.01.
# [001293.80] [0/1] 12-12 02:38  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0426.
# [001293.89] [0/1] 12-12 02:38  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.299.
# [001293.90] [0/1] 12-12 02:38  Diagnostics               INFO     - max Geweke is 1.09.
# [001293.90] [0/1] 12-12 02:38  Diagnostics               INFO     - Geweke p-value is 0.404.
# [001293.90] [0/1] 12-12 02:38  Diagnostics               INFO     - effective sample size = (3900 iterations / integrated autocorrelation time) (reliable) is 86.1.
# [001293.90] [0/1] 12-12 02:38  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.138.
# [001293.91] [0/1] 12-12 02:38  Diagnostics               INFO     - current mean acceptance rate is 0.667.
# [001293.91] [0/1] 12-12 02:38  Diagnostics               INFO     - total mean acceptance rate is 0.545.
# [001293.92] [0/1] 12-12 02:38  MCMCSampler               INFO     Updating proposal covariance.
# [001324.12] [0/1] 12-12 02:38  MCMCSampler               INFO     354 steps, acceptance rate 0.638.
# [001336.31] [0/1] 12-12 02:38  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001336.32] [0/1] 12-12 02:38  MCMCSampler               INFO     Diagnostics:
# [001336.33] [0/1] 12-12 02:38  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.108; not < 0.01.
# [001336.34] [0/1] 12-12 02:38  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.122.
# [001336.39] [0/1] 12-12 02:38  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.348.
# [001336.40] [0/1] 12-12 02:38  Diagnostics               INFO     - max Geweke is 0.665.
# [001336.40] [0/1] 12-12 02:38  Diagnostics               INFO     - Geweke p-value is 0.441.
# [001336.41] [0/1] 12-12 02:38  Diagnostics               INFO     - effective sample size = (4050 iterations / integrated autocorrelation time) (reliable) is 89.4.
# [001336.41] [0/1] 12-12 02:38  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0113.
# [001336.41] [0/1] 12-12 02:38  Diagnostics               INFO     - current mean acceptance rate is 0.619.
# [001336.41] [0/1] 12-12 02:38  Diagnostics               INFO     - total mean acceptance rate is 0.548.
# [001336.42] [0/1] 12-12 02:38  MCMCSampler               INFO     Updating proposal covariance.
# [001368.07] [0/1] 12-12 02:39  MCMCSampler               INFO     299 steps, acceptance rate 0.589.
# [001387.32] [0/1] 12-12 02:39  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001387.33] [0/1] 12-12 02:39  MCMCSampler               INFO     Diagnostics:
# [001387.34] [0/1] 12-12 02:39  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0836; not < 0.01.
# [001387.35] [0/1] 12-12 02:39  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0935.
# [001387.40] [0/1] 12-12 02:39  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.136.
# [001387.41] [0/1] 12-12 02:39  Diagnostics               INFO     - max Geweke is 0.886.
# [001387.41] [0/1] 12-12 02:39  Diagnostics               INFO     - Geweke p-value is 0.193.
# [001387.42] [0/1] 12-12 02:39  Diagnostics               INFO     - effective sample size = (4200 iterations / integrated autocorrelation time) (reliable) is 89.1.
# [001387.42] [0/1] 12-12 02:39  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0395.
# [001387.42] [0/1] 12-12 02:39  Diagnostics               INFO     - current mean acceptance rate is 0.577.
# [001387.42] [0/1] 12-12 02:39  Diagnostics               INFO     - total mean acceptance rate is 0.549.
# [001387.45] [0/1] 12-12 02:39  MCMCSampler               INFO     Updating proposal covariance.
# [001418.19] [0/1] 12-12 02:40  MCMCSampler               INFO     398 steps, acceptance rate 0.603.
# [001429.39] [0/1] 12-12 02:40  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001429.40] [0/1] 12-12 02:40  MCMCSampler               INFO     Diagnostics:
# [001429.41] [0/1] 12-12 02:40  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.113; not < 0.01.
# [001429.42] [0/1] 12-12 02:40  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0239.
# [001429.47] [0/1] 12-12 02:40  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.219.
# [001429.48] [0/1] 12-12 02:40  Diagnostics               INFO     - max Geweke is 0.599.
# [001429.48] [0/1] 12-12 02:40  Diagnostics               INFO     - Geweke p-value is 0.358.
# [001429.49] [0/1] 12-12 02:40  Diagnostics               INFO     - effective sample size = (4350 iterations / integrated autocorrelation time) (reliable) is 105.
# [001429.49] [0/1] 12-12 02:40  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.136.
# [001429.49] [0/1] 12-12 02:40  Diagnostics               INFO     - current mean acceptance rate is 0.599.
# [001429.49] [0/1] 12-12 02:40  Diagnostics               INFO     - total mean acceptance rate is 0.55.
# [001429.50] [0/1] 12-12 02:40  MCMCSampler               INFO     Updating proposal covariance.
# [001460.33] [0/1] 12-12 02:40  MCMCSampler               INFO     315 steps, acceptance rate 0.625.
# [001477.77] [0/1] 12-12 02:41  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001477.78] [0/1] 12-12 02:41  MCMCSampler               INFO     Diagnostics:
# [001477.79] [0/1] 12-12 02:41  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.138; not < 0.01.
# [001477.81] [0/1] 12-12 02:41  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0401.
# [001477.86] [0/1] 12-12 02:41  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.192.
# [001477.86] [0/1] 12-12 02:41  Diagnostics               INFO     - max Geweke is 0.729.
# [001477.87] [0/1] 12-12 02:41  Diagnostics               INFO     - Geweke p-value is 0.585.
# [001477.87] [0/1] 12-12 02:41  Diagnostics               INFO     - effective sample size = (4500 iterations / integrated autocorrelation time) (reliable) is 109.
# [001477.87] [0/1] 12-12 02:41  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0385.
# [001477.87] [0/1] 12-12 02:41  Diagnostics               INFO     - current mean acceptance rate is 0.601.
# [001477.87] [0/1] 12-12 02:41  Diagnostics               INFO     - total mean acceptance rate is 0.552.
# [001477.89] [0/1] 12-12 02:41  MCMCSampler               INFO     Updating proposal covariance.
# [001508.18] [0/1] 12-12 02:41  MCMCSampler               INFO     307 steps, acceptance rate 0.577.
# [001529.38] [0/1] 12-12 02:41  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001529.38] [0/1] 12-12 02:41  MCMCSampler               INFO     Diagnostics:
# [001529.39] [0/1] 12-12 02:41  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.215; not < 0.01.
# [001529.40] [0/1] 12-12 02:41  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0751.
# [001529.44] [0/1] 12-12 02:41  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.36.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - max Geweke is 0.543.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - Geweke p-value is 0.422.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - effective sample size = (4650 iterations / integrated autocorrelation time) (reliable) is 107.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0676.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - current mean acceptance rate is 0.577.
# [001529.45] [0/1] 12-12 02:41  Diagnostics               INFO     - total mean acceptance rate is 0.552.
# [001529.46] [0/1] 12-12 02:41  MCMCSampler               INFO     Updating proposal covariance.
# [001560.22] [0/1] 12-12 02:42  MCMCSampler               INFO     380 steps, acceptance rate 0.600.
# [001571.11] [0/1] 12-12 02:42  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001571.12] [0/1] 12-12 02:42  MCMCSampler               INFO     Diagnostics:
# [001571.13] [0/1] 12-12 02:42  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0747; not < 0.01.
# [001571.14] [0/1] 12-12 02:42  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.0647.
# [001571.19] [0/1] 12-12 02:42  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.128.
# [001571.20] [0/1] 12-12 02:42  Diagnostics               INFO     - max Geweke is 0.631.
# [001571.20] [0/1] 12-12 02:42  Diagnostics               INFO     - Geweke p-value is 0.123.
# [001571.20] [0/1] 12-12 02:42  Diagnostics               INFO     - effective sample size = (4800 iterations / integrated autocorrelation time) (reliable) is 119.
# [001571.20] [0/1] 12-12 02:42  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0731.
# [001571.21] [0/1] 12-12 02:42  Diagnostics               INFO     - current mean acceptance rate is 0.587.
# [001571.21] [0/1] 12-12 02:42  Diagnostics               INFO     - total mean acceptance rate is 0.554.
# [001572.19] [0/1] 12-12 02:42  MCMCSampler               INFO     Updating proposal covariance.
# [001602.26] [0/1] 12-12 02:43  MCMCSampler               INFO     280 steps, acceptance rate 0.618.
# [001623.13] [0/1] 12-12 02:43  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001623.14] [0/1] 12-12 02:43  MCMCSampler               INFO     Diagnostics:
# [001623.15] [0/1] 12-12 02:43  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0374; not < 0.01.
# [001623.16] [0/1] 12-12 02:43  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.04.
# [001623.22] [0/1] 12-12 02:43  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0853.
# [001623.22] [0/1] 12-12 02:43  Diagnostics               INFO     - max Geweke is 0.94.
# [001623.22] [0/1] 12-12 02:43  Diagnostics               INFO     - Geweke p-value is 0.435.
# [001623.23] [0/1] 12-12 02:43  Diagnostics               INFO     - effective sample size = (4950 iterations / integrated autocorrelation time) (reliable) is 126.
# [001623.23] [0/1] 12-12 02:43  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.03.
# [001623.23] [0/1] 12-12 02:43  Diagnostics               INFO     - current mean acceptance rate is 0.625.
# [001623.23] [0/1] 12-12 02:43  Diagnostics               INFO     - total mean acceptance rate is 0.555.
# [001623.25] [0/1] 12-12 02:43  MCMCSampler               INFO     Updating proposal covariance.
# [001641.08] [0/1] 12-12 02:43  Chain                     INFO     Saving ../_tests/chain_wigglez_d_b1_omega_cdm.npy.
# [001641.09] [0/1] 12-12 02:43  MCMCSampler               INFO     Diagnostics:
# [001641.10] [0/1] 12-12 02:43  Diagnostics               INFO     - max eigen Gelman-Rubin - 1 is 0.0664; not < 0.01.
# [001641.11] [0/1] 12-12 02:43  Diagnostics               INFO     - max diag Gelman-Rubin - 1 is 0.051.
# [001641.16] [0/1] 12-12 02:43  Diagnostics               INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.137.
# [001641.17] [0/1] 12-12 02:43  Diagnostics               INFO     - max Geweke is 1.21.
# [001641.17] [0/1] 12-12 02:43  Diagnostics               INFO     - Geweke p-value is 0.282.
# [001641.17] [0/1] 12-12 02:43  Diagnostics               INFO     - effective sample size = (5000 iterations / integrated autocorrelation time) (reliable) is 128.
# [001641.18] [0/1] 12-12 02:43  Diagnostics               INFO     - max variation of integrated autocorrelation time is 0.0156.
# [001641.18] [0/1] 12-12 02:43  Diagnostics               INFO     - current mean acceptance rate is 0.578.
# [001641.18] [0/1] 12-12 02:43  Diagnostics               INFO     - total mean acceptance rate is 0.556.
