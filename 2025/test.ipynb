# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
u = np.random.uniform(size=40)

# %%
plt.scatter(u,u*0)

# %%
u.min()
# Out:
# 0.008485133807487832

# %%
u = [np.random.uniform(size=40).min() for i in range(1000)]

# %%
import scipy
x = np.linspace(0,0.2,1000)

plt.hist(u,bins=100, density=True);
plt.plot(x,scipy.stats.beta(1,40).pdf(x));
